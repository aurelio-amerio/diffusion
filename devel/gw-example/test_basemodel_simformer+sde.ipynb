# %%
# we define a simformer using our SDE model

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('./src')
sys.path.append('./reference/simformer-main/src/probjax')
sys.path.append('./reference/simformer-main/src/scoresbibm')

sys.path.append('../src')
sys.path.append('../reference/simformer-main/src/probjax')
sys.path.append('../reference/simformer-main/src/scoresbibm')

import os
# os.environ['JAX_PLATFORMS']="cpu"

import jax 
import jax.numpy as jnp
import numpy as np

import haiku as hk

# import torch

import matplotlib.pyplot as plt

# from scoresbibm.tasks import get_task
# from scoresbibm.methods.score_transformer import run_train_transformer_model
# from scoresbibm.methods.neural_nets import scalar_transformer_model
from scoresbibm.methods.sde import init_sde_related
# from scoresbibm.utils.plot import use_style

from tqdm.auto import tqdm

# %%
import diffusion
from diffusion.sbi.transformer import Transformer
from diffusion.embedding import GaussianFourierEmbedding, SinusoidalEmbedding
from diffusion import sde as sde_ours

# %%
print(jax.default_backend())
print(jax.devices())
# Out:
# gpu
# [CudaDevice(id=0)]

# %%
train=True

# %% [markdown]
# # generate dataset

# %%
# we have two parameters, theta1 and theta2
# we have two outputs, y1 and y2, corresponding to the measurement with two different detectors

npoints = 2**10 #1024

nobs = 128_000
wavefun = lambda theta1, theta2, x: jnp.sin(theta1*x)*jnp.cos(theta2*x)


rng = jax.random.PRNGKey(42)
rng, key = jax.random.split(rng)
x1 = np.linspace(0, 4*np.pi, npoints).reshape(1,-1)
x2 = np.linspace(0, 4*np.pi, npoints).reshape(1,-1)
thetas = jax.random.normal(key, (nobs,2))+0.5
noise1 = jax.random.normal(key, (nobs,npoints))*0.3
noise2 = jax.random.normal(key, (nobs,npoints))*0.3

xs1 = wavefun(thetas[:,0:1], thetas[:,1:2],x1) + noise1
xs2 = wavefun(thetas[:,0:1], thetas[:,1:2],x2) + noise2

xs1 = xs1.reshape(nobs,1,npoints)
xs2 = xs2.reshape(nobs,1,npoints)

xs = jnp.concatenate([xs1,xs2],axis=1)

# %%
xs.shape, thetas.shape
# Out:
# ((128000, 2, 1024), (128000, 2))

# %%
i=5
plt.plot(x1[0,:], xs1[i,0,:], label='y1')
plt.plot(x2[0,:], xs2[i,0,:], label='y2')
plt.legend()
plt.show()

# %% [markdown]
# # data preprocessing

# %%
# thetas = jax.device_put(thetas, jax.devices("cpu")[0])
# xs = jax.device_put(xs, jax.devices("cpu")[0])

# %%
thetas_mean = jnp.mean(thetas, axis=0, keepdims=True)
thetas_std = jnp.std(thetas, axis=0, keepdims=True)

thetas = (thetas - thetas_mean) / thetas_std

# %%
def z_score_thetas(thetas):
    thetas = (thetas - thetas_mean) / thetas_std
    return thetas

def un_z_score_thetas(thetas):
    thetas = thetas * thetas_std + thetas_mean
    return thetas

# %%
xs_mean = jnp.mean(xs, axis=0, keepdims=True)
xs_mean = jnp.mean(xs_mean, axis=-1, keepdims=True)
xs_std = jnp.std(xs, axis=0, keepdims=True)
xs_std = jnp.std(xs_std, axis=-1, keepdims=True)

xs = (xs - xs_mean) / xs_std

# %%
def z_score_xs(xs):
    xs = (xs - xs_mean) / xs_std
    return xs

def un_z_score_xs(xs):
    xs = xs * xs_std + xs_mean
    return xs

# %%
def ravel(data, axis=-1):
    flat_data, tree = jax.tree_util.tree_flatten(data)
    split_dims = np.cumsum(np.array([flat.shape[axis] for flat in flat_data]))[:-1]
    flat_data = jnp.concatenate(flat_data, axis=axis)
    def unravel(flat_data):
        flat_data = jnp.split(flat_data, split_dims, axis=axis)
        flat_data = jax.tree_util.tree_unflatten(tree, flat_data)
        return flat_data
    def unflatten(flat_data):
        flat_data = jnp.split(flat_data, split_dims, axis=axis)
        return flat_data 
    return flat_data, unravel, unflatten

# %%
data = {"theta0": thetas[:, 0][:, None], "theta1": thetas[:, 1][:, None], "x0": xs[:, 0], "x1": xs[:, 1]}
data_flat, unravel, unflatten = ravel(data)
theta_dim = 2
x_dim = data_flat.shape[-1] - theta_dim
node_id = jnp.arange(0, 4)
condition_mask = jnp.array([False]*theta_dim + [True]*x_dim)

# %%
sde, T_min, T_max, weight_fn, output_scale_fn =  init_sde_related(data_flat, "vesde", sigma_min=1e-5, sigma_max=15.)

# %%
sde.event_shape
# Out:
# (2050,)

# %%
ve = sde_ours.VESDE(2050, sigma_min=1e-5, sigma_max=15.)

# %%
data_flat.shape
# Out:
# (128000, 2050)

# %%
m1=sde.marginal_mean(jnp.ones(10), data_flat[:10, :]).shape

# %%
m2=ve.marginal_mean(data_flat[:10, :],jnp.ones((10,1))).shape

# %%
from probjax.nn.helpers import GaussianFourierEmbedding
from probjax.nn.transformers import Transformer


token_dim = 100
id_dim = 40
cond_dim = 10

embedding_net1 = lambda x: jnp.repeat(x, token_dim, axis=-1)

embedding_net2 = lambda x:hk.Sequential([
        hk.Conv1D(output_channels=16, kernel_shape=9, stride=2, padding='SAME', name='conv1'), # 512
        jax.nn.gelu,
        hk.Conv1D(output_channels=32, kernel_shape=6, stride=2, padding='SAME', name='conv2'), # 256
        jax.nn.gelu,
        hk.Conv1D(output_channels=64, kernel_shape=3, stride=2, padding='SAME', name='conv3'), # 128
        jax.nn.gelu,
        hk.Conv1D(output_channels=128, kernel_shape=3, stride=2, padding='SAME', name='conv4'), # 64
        jax.nn.gelu,
        hk.Conv1D(output_channels=256, kernel_shape=3, stride=2, padding='SAME', name='conv4'), # 32
        jax.nn.gelu,
        hk.Conv1D(output_channels=256, kernel_shape=3, stride=2, padding='SAME', name='conv4'), # 16
        jax.nn.gelu,
        hk.Conv1D(output_channels=512, kernel_shape=3, stride=2, padding='SAME', name='conv4'), # 8
        jax.nn.gelu,
        hk.Conv1D(output_channels=512, kernel_shape=3, stride=2, padding='SAME', name='conv4'), # 4
        jax.nn.gelu,
        hk.Flatten(),
        hk.Linear(token_dim, name='linear'),
    ])(x)[..., None,:]

embedding_nets = [embedding_net1,embedding_net1, embedding_net2, embedding_net2]
output_fn = [lambda x: hk.Linear(1)(x), lambda x: hk.Linear(1)(x), lambda x: hk.Linear(npoints)(x), lambda x: hk.Linear(npoints)(x)]


def model(t, data, data_id, condition_mask, edge_mask=None):
    
    data = unflatten(data)

    assert len(data) == len(embedding_nets), "Number of data elements and embedding nets must match"
    
    data_embedded = jax.tree.map(lambda x, net: net(x[..., :,None]), data, embedding_nets)

    data_embedded = jnp.concatenate(data_embedded, axis=-2)
    
    _, current_nodes, _ = data_embedded.shape
    
    time_embeder = GaussianFourierEmbedding(128)
    id_embedder= hk.Embed(4, id_dim)
    
    id_embedding = id_embedder(data_id)
    id_embedding = jnp.broadcast_to(
        id_embedding, data_embedded.shape[:-1] + (id_dim,)
    )
    tokens = jnp.concatenate([data_embedded, id_embedding], axis=-1)
    time = time_embeder(t[..., None])
    
    condition_token = hk.get_parameter(
        "condition_token",
        shape=[1, 1, cond_dim],
        init=hk.initializers.RandomNormal(
            0.01, 0.
        ),
    )
    condition_mask = unflatten(condition_mask)
    condition_mask = jax.tree.map(lambda x: jnp.any(x, axis=-1, keepdims=True), condition_mask)
    condition_mask = jnp.concatenate(condition_mask, axis=-1)
    condition_mask = condition_mask.reshape(-1, current_nodes, 1)
    condition_token = condition_mask * condition_token
  
    condition_token = jnp.broadcast_to(
        condition_token, tokens.shape[:-1] + (cond_dim,)
    )
    tokens = jnp.concatenate([tokens, condition_token], -1)

    
    model = Transformer(
        num_heads=4,
        num_layers=8,
        attn_size=20,
        widening_factor=3,
    )
    
    h = model(tokens, context=time, mask=edge_mask)
    out = jnp.split(h, current_nodes, axis=-2)
    out = jax.tree.map(lambda x, fn: fn(x), out, output_fn)
    out = jnp.concatenate(out, axis=-1)
    out = jnp.squeeze(out, axis=-2)
    out = output_scale_fn(t, out)

    return out
    
    
init_fn, model_fn = hk.without_apply_rng(hk.transform(model))

# %%
params = init_fn(jax.random.PRNGKey(42), jnp.ones((1,)), data_flat[:10], node_id, condition_mask)

# %%
out = model_fn(params, jnp.ones((1,))*0.01, data_flat[:10], node_id, condition_mask)

# %%
out.shape
# Out:
# (10, 2050)

# %%
import optax
optimizer = optax.adam(1e-4)
opt_state = optimizer.init(params)

# %%
from probjax.nn.loss_fn import denoising_score_matching_loss
from functools import partial




@jax.jit
def loss_fn(params, key, data, node_id):
    key_times, key_loss, key_condition = jax.random.split(key,3)
    times = jax.random.uniform(key_times, (data.shape[0],), minval=T_min, maxval =T_max)
    condition_mask1 = jnp.array([False]*theta_dim + [True]*x_dim)
    condition_mask2 = jnp.array([False]*theta_dim + [True]*(x_dim//2) + [False]*(x_dim//2))
    condition_mask3 = jnp.array([False]*theta_dim + [False]*(x_dim//2) + [True]*(x_dim//2))

    edge_mask1 = jnp.ones((4,4), dtype=bool)
    # Partial posterior
    edge_mask2 = edge_mask1.at[:, 2].set(False)
    edge_mask2 = edge_mask2.at[2, :].set(False)
    # Partial posterior 2
    edge_mask3 = edge_mask1.at[:, 3].set(False)
    edge_mask3 = edge_mask3.at[3, :].set(False)
    
    edge_masks = jax.random.choice(key_condition, jnp.stack([edge_mask1, edge_mask2, edge_mask3]), (data.shape[0],))
    condition_mask = jax.random.choice(key_condition, jnp.stack([condition_mask1, condition_mask2, condition_mask3]), (data.shape[0],))
    l_mask = jnp.broadcast_to(condition_mask1, (data.shape[0],) + condition_mask1.shape)

    mean_fn = lambda times, xs_target: ve.marginal_mean(xs_target, times.reshape(-1,1))
    std_fn = lambda times, xs_target: ve.marginal_stddev(xs_target, times.reshape(-1,1))
    
    loss = denoising_score_matching_loss(params, key_loss, times, data, l_mask, node_id, model_fn = model_fn, mean_fn = mean_fn, std_fn=std_fn, weight_fn=weight_fn, edge_mask=edge_masks, condition_mask=condition_mask, axis=-1)
    return loss


# @jax.jit
# def loss_fn(params, key, data, node_id):
#     key_times, key_loss, key_condition = jax.random.split(key,3)

#     loss_fn_ = ve.get_loss_function()

#     #times = jax.random.uniform(key_times, (data.shape[0],), minval=T_min, maxval =T_max)
#     condition_mask1 = jnp.array([False]*theta_dim + [True]*x_dim)
#     condition_mask2 = jnp.array([False]*theta_dim + [True]*(x_dim//2) + [False]*(x_dim//2))
#     condition_mask3 = jnp.array([False]*theta_dim + [False]*(x_dim//2) + [True]*(x_dim//2))

#     edge_mask1 = jnp.ones((4,4), dtype=bool)
#     # Partial posterior
#     edge_mask2 = edge_mask1.at[:, 2].set(False)
#     edge_mask2 = edge_mask2.at[2, :].set(False)
#     # Partial posterior 2
#     edge_mask3 = edge_mask1.at[:, 3].set(False)
#     edge_mask3 = edge_mask3.at[3, :].set(False)
    
#     edge_masks = jax.random.choice(key_condition, jnp.stack([edge_mask1, edge_mask2, edge_mask3]), (data.shape[0],))
#     condition_mask = jax.random.choice(key_condition, jnp.stack([condition_mask1, condition_mask2, condition_mask3]), (data.shape[0],))
#     l_mask = jnp.broadcast_to(condition_mask1, (data.shape[0],) + condition_mask1.shape)

#     def score_model(xs_t, times, *args, **kwargs):
#         return model_fn(params, times, xs_t, *args, **kwargs)

#     loss = loss_fn_(score_model, data, l_mask, node_id, rng=key_loss, edge_mask=edge_masks, condition_mask=condition_mask)

#     return loss



@partial(jax.pmap, axis_name="num_devices")
def update(params, opt_state, key, data, node_id):
    loss, grads = jax.value_and_grad(loss_fn)(params, key, data, node_id)

    loss = jax.lax.pmean(loss, axis_name="num_devices")
    grads = jax.lax.pmean(grads, axis_name="num_devices")
    
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return loss, params, opt_state

# %%
n_devices = jax.local_device_count()
replicated_params = jax.tree.map(lambda x: jnp.array([x] * n_devices), params)
replicated_opt_state = jax.tree.map(lambda x: jnp.array([x] * n_devices), opt_state)

# %%
key = jax.random.PRNGKey(0)

# %%
nepochs = 5
batch_size = 128
batch_steps = nobs // batch_size // n_devices
print(batch_steps)
# Out:
# 1000

# %%
#don't retrain
if train:
    node_id_repeated = node_id[None, ...]
    node_id_repeated = jnp.repeat(node_id_repeated, n_devices, axis=0)
    
    nepochs = 5
    batch_size = 128
    batch_steps = nobs // batch_size // n_devices
    
    pbar = tqdm(range(nepochs))
    
    for _ in pbar:
        l = 0
        key, subkey = jax.random.split(key)
        data_batches = jax.random.choice(subkey, data_flat, (batch_steps, n_devices, batch_size), replace=False)
        for j in range(batch_steps):
            loss, replicated_params, replicated_opt_state = update(replicated_params, replicated_opt_state, jax.random.split(subkey, (n_devices,)), data_batches[j], node_id_repeated)
            l += loss.item()
            if j+1 % 10 == 0:
                pbar.set_postfix(loss=l/(j+1), j=j)
        # print(l)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
params = jax.tree.map(lambda x: x[0], replicated_params)

# %%
jnp.save("only_post_params.pt", params)
# params = jnp.load("only_post_params.pt.npy", allow_pickle=True).item()

# %%
end_mean = sde.marginal_mean(jnp.array(1.0))[None, ...]
end_mean = jax.device_put(end_mean, jax.devices()[0])

# %%
end_std = sde.marginal_stddev(jnp.array(1.0))[None, ...]
end_std = jax.device_put(end_std, jax.devices()[0])

# %% [markdown]
# # now we do the backward diffusion to get the posterior

# %%
nobs = 100

rng = jax.random.PRNGKey(420)
rng, key = jax.random.split(rng)
x1 = np.linspace(0, 4*np.pi, npoints).reshape(1,-1)
x2 = np.linspace(0, 4*np.pi, npoints).reshape(1,-1)
thetas_test = jax.random.normal(key, (nobs,2))+0.2
noise1 = jax.random.normal(key, (nobs,npoints))*0.3
noise2 = jax.random.normal(key, (nobs,npoints))*0.3

xs1 = wavefun(thetas_test[:,0:1], thetas_test[:,1:2],x1) + noise1
xs2 = wavefun(thetas_test[:,0:1], thetas_test[:,1:2],x2) + noise2

xs1 = xs1.reshape(nobs,1,npoints)
xs2 = xs2.reshape(nobs,1,npoints)

xs_test = jnp.concatenate([xs1,xs2],axis=1)

# %%
thetas_test = (thetas_test - thetas_mean) / thetas_std
xs_test = (xs_test - xs_mean) / xs_std

# %%
data_test = {"theta0": thetas_test[:, 0][:, None], "theta1": thetas_test[:, 1][:, None], "x0": xs_test[:, 0], "x1": xs_test[:, 1]}
data_test_flat, _, _ = ravel(data_test)

# %%
edge_mask = jnp.ones((4,4), dtype=bool)
edge_mask1 = edge_mask.at[:, 2].set(False)
edge_mask1 = edge_mask1.at[2, :].set(False)

edge_mask2 = edge_mask.at[:, 3].set(False)
edge_mask2 = edge_mask2.at[3, :].set(False)

# %%
index = 42
x_o = jax.device_put(data_test_flat[index], jax.devices("gpu")[0])
x_o[:2]
# Out:
# Array([-0.717,  1.153], dtype=float32)

# %%
score_fn = lambda x, t, data_id, condition_mask, edge_mask: model_fn(params, jnp.atleast_1d(t), jnp.atleast_2d(x), data_id, condition_mask, edge_mask)

# %%
rev = ve.reverse(score_fn)

# %%
rng = jax.random.PRNGKey(42)
score_args = {"data_id": node_id, "condition_mask": condition_mask, "edge_mask": edge_mask}
sample = rev.sample(rng, 1000, condition_mask=condition_mask, condition_value=x_o, score_args=score_args)
# Out:
# E0122 10:44:59.195135   39462 buffer_comparator.cc:157] Difference at 16: 0.36074, expected 20.3839
# E0122 10:44:59.195240   39462 buffer_comparator.cc:157] Difference at 17: -0.634934, expected 18.5035
# E0122 10:44:59.195249   39462 buffer_comparator.cc:157] Difference at 18: 0.0440229, expected 20.642
# E0122 10:44:59.195260   39462 buffer_comparator.cc:157] Difference at 19: 0.892309, expected 22.8657
# E0122 10:44:59.195267   39462 buffer_comparator.cc:157] Difference at 20: 1.41359, expected 19.498
# E0122 10:44:59.195274   39462 buffer_comparator.cc:157] Difference at 21: -0.223473, expected 18.8688
# E0122 10:44:59.195281   39462 buffer_comparator.cc:157] Difference at 22: -1.0031, expected 19.8339
# E0122 10:44:59.195288   39462 buffer_comparator.cc:157] Difference at 23: -0.324668, expected 19.7669
# E0122 10:44:59.195294   39462 buffer_comparator.cc:157] Difference at 24: 0.875558, expected 19.6552
# E0122 10:44:59.195301   39462 buffer_comparator.cc:157] Difference at 25: 0.540549, expected 19.6648
# 2025-01-22 10:44:59.195330: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.197341   39462 buffer_comparator.cc:157] Difference at 16: 0.36074, expected 20.3839
# E0122 10:44:59.197367   39462 buffer_comparator.cc:157] Difference at 17: -0.634934, expected 18.5035
# E0122 10:44:59.197375   39462 buffer_comparator.cc:157] Difference at 18: 0.0440229, expected 20.642
# E0122 10:44:59.197382   39462 buffer_comparator.cc:157] Difference at 19: 0.892309, expected 22.8657
# E0122 10:44:59.197389   39462 buffer_comparator.cc:157] Difference at 20: 1.41359, expected 19.498
# E0122 10:44:59.197395   39462 buffer_comparator.cc:157] Difference at 21: -0.223473, expected 18.8688
# E0122 10:44:59.197402   39462 buffer_comparator.cc:157] Difference at 22: -1.0031, expected 19.8339
# E0122 10:44:59.197409   39462 buffer_comparator.cc:157] Difference at 23: -0.324668, expected 19.7669
# E0122 10:44:59.197415   39462 buffer_comparator.cc:157] Difference at 24: 0.875558, expected 19.6552
# E0122 10:44:59.197422   39462 buffer_comparator.cc:157] Difference at 25: 0.540549, expected 19.6648
# 2025-01-22 10:44:59.197440: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.199399   39462 buffer_comparator.cc:157] Difference at 64: -0.939403, expected 18.4917
# E0122 10:44:59.199426   39462 buffer_comparator.cc:157] Difference at 65: 0.766245, expected 16.8939
# E0122 10:44:59.199433   39462 buffer_comparator.cc:157] Difference at 66: 0.0563677, expected 19.9204
# E0122 10:44:59.199440   39462 buffer_comparator.cc:157] Difference at 67: -0.353637, expected 20.0645
# E0122 10:44:59.199447   39462 buffer_comparator.cc:157] Difference at 68: 1.58472, expected 19.1005
# E0122 10:44:59.199453   39462 buffer_comparator.cc:157] Difference at 69: 0.132068, expected 19.7801
# E0122 10:44:59.199460   39462 buffer_comparator.cc:157] Difference at 70: 0.493231, expected 18.714
# E0122 10:44:59.199467   39462 buffer_comparator.cc:157] Difference at 71: 0.980325, expected 20.03
# E0122 10:44:59.199473   39462 buffer_comparator.cc:157] Difference at 72: -0.799146, expected 20.2059
# E0122 10:44:59.199480   39462 buffer_comparator.cc:157] Difference at 73: -1.17561, expected 15.651
# 2025-01-22 10:44:59.199500: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.201406   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.201432   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.201439   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.201446   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.201453   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.201459   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.201466   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.201473   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.201479   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.201486   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.201507: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.203493   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.203518   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.203525   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.203531   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.203538   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.203547   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.203554   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.203560   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.203570   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.203576   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.203594: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.205447   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.205471   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.205478   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.205485   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.205493   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.205500   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.205509   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.205515   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.205523   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.205530   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.205558: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.207330   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.207353   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.207361   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.207400   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.207406   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.207413   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.207421   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.207427   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.207436   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.207443   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.207460: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.209184   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.209208   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.209215   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.209223   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.209230   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.209237   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.209244   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.209250   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.209260   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.209266   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.209285: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.211075   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.211099   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.211106   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.211113   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.211121   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.211130   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.211137   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.211143   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.211151   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.211158   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.211173: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.213167   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.213192   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.213199   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.213205   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.213214   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.213222   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.213232   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.213238   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.213245   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.213252   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.213268: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.215132   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.215156   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.215163   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.215169   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.215179   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.215185   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.215193   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.215201   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.215208   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.215215   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.215231: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.217169   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.217193   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.217201   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.217207   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.217215   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.217222   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.217231   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.217237   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.217245   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.217251   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.217274: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.219052   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.219075   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.219082   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.219092   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.219098   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.219106   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.219113   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.219120   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.219127   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.219135   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.219151: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.221004   39462 buffer_comparator.cc:157] Difference at 128: -1.15835, expected 22.0223
# E0122 10:44:59.221030   39462 buffer_comparator.cc:157] Difference at 129: -0.962631, expected 22.3161
# E0122 10:44:59.221038   39462 buffer_comparator.cc:157] Difference at 130: 0.895347, expected 20.7784
# E0122 10:44:59.221045   39462 buffer_comparator.cc:157] Difference at 131: 1.06207, expected 21.1129
# E0122 10:44:59.221052   39462 buffer_comparator.cc:157] Difference at 132: -1.28395, expected 19.3851
# E0122 10:44:59.221060   39462 buffer_comparator.cc:157] Difference at 133: -1.6709, expected 18.7666
# E0122 10:44:59.221067   39462 buffer_comparator.cc:157] Difference at 134: 0.406548, expected 19.7335
# E0122 10:44:59.221077   39462 buffer_comparator.cc:157] Difference at 135: 0.928536, expected 20.0339
# E0122 10:44:59.221085   39462 buffer_comparator.cc:157] Difference at 136: 0.380218, expected 17.5017
# E0122 10:44:59.221093   39462 buffer_comparator.cc:157] Difference at 137: -0.163186, expected 20.7348
# 2025-01-22 10:44:59.221112: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.227491   39462 buffer_comparator.cc:157] Difference at 0: 37.0654, expected 21.9201
# E0122 10:44:59.227518   39462 buffer_comparator.cc:157] Difference at 1: 33.5306, expected 20.8818
# E0122 10:44:59.227526   39462 buffer_comparator.cc:157] Difference at 2: 29.4933, expected 18.8976
# E0122 10:44:59.227533   39462 buffer_comparator.cc:157] Difference at 3: 35.699, expected 21.6884
# E0122 10:44:59.227568   39462 buffer_comparator.cc:157] Difference at 4: 29.739, expected 17.0756
# E0122 10:44:59.227575   39462 buffer_comparator.cc:157] Difference at 5: 32.8416, expected 19.6786
# E0122 10:44:59.227583   39462 buffer_comparator.cc:157] Difference at 6: 33.5857, expected 20.752
# E0122 10:44:59.227592   39462 buffer_comparator.cc:157] Difference at 7: 31.7493, expected 19.1735
# E0122 10:44:59.227601   39462 buffer_comparator.cc:157] Difference at 8: 33.2169, expected 20.1605
# E0122 10:44:59.227608   39462 buffer_comparator.cc:157] Difference at 9: 31.5815, expected 19.3074
# 2025-01-22 10:44:59.227624: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.245887   39462 buffer_comparator.cc:157] Difference at 16: 0, expected -501.195
# E0122 10:44:59.245946   39462 buffer_comparator.cc:157] Difference at 17: 0, expected -510.363
# E0122 10:44:59.245954   39462 buffer_comparator.cc:157] Difference at 18: -0, expected -514.237
# E0122 10:44:59.245961   39462 buffer_comparator.cc:157] Difference at 19: -0, expected -521.746
# E0122 10:44:59.245968   39462 buffer_comparator.cc:157] Difference at 20: 0, expected -500.013
# E0122 10:44:59.245975   39462 buffer_comparator.cc:157] Difference at 21: -0, expected -500.387
# E0122 10:44:59.245981   39462 buffer_comparator.cc:157] Difference at 22: -0, expected -505.002
# E0122 10:44:59.245988   39462 buffer_comparator.cc:157] Difference at 23: -0, expected -511.46
# E0122 10:44:59.245995   39462 buffer_comparator.cc:157] Difference at 24: -0, expected -518.995
# E0122 10:44:59.246004   39462 buffer_comparator.cc:157] Difference at 25: 0, expected -500.764
# 2025-01-22 10:44:59.246031: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.252645   39462 buffer_comparator.cc:157] Difference at 16: 0, expected -501.195
# E0122 10:44:59.252695   39462 buffer_comparator.cc:157] Difference at 17: 0, expected -510.363
# E0122 10:44:59.252703   39462 buffer_comparator.cc:157] Difference at 18: -0, expected -514.237
# E0122 10:44:59.252712   39462 buffer_comparator.cc:157] Difference at 19: -0, expected -521.746
# E0122 10:44:59.252719   39462 buffer_comparator.cc:157] Difference at 20: 0, expected -500.013
# E0122 10:44:59.252726   39462 buffer_comparator.cc:157] Difference at 21: -0, expected -500.387
# E0122 10:44:59.252734   39462 buffer_comparator.cc:157] Difference at 22: -0, expected -505.002
# E0122 10:44:59.252740   39462 buffer_comparator.cc:157] Difference at 23: -0, expected -511.46
# E0122 10:44:59.252747   39462 buffer_comparator.cc:157] Difference at 24: -0, expected -518.995
# E0122 10:44:59.252755   39462 buffer_comparator.cc:157] Difference at 25: 0, expected -500.764
# 2025-01-22 10:44:59.252770: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.258267   39462 buffer_comparator.cc:157] Difference at 64: 0, expected -512.392
# E0122 10:44:59.258323   39462 buffer_comparator.cc:157] Difference at 65: -0, expected -498.585
# E0122 10:44:59.258330   39462 buffer_comparator.cc:157] Difference at 66: -0, expected -502.718
# E0122 10:44:59.258337   39462 buffer_comparator.cc:157] Difference at 67: 0, expected -516.905
# E0122 10:44:59.258343   39462 buffer_comparator.cc:157] Difference at 68: -0, expected -509.45
# E0122 10:44:59.258351   39462 buffer_comparator.cc:157] Difference at 69: 0, expected -501.301
# E0122 10:44:59.258358   39462 buffer_comparator.cc:157] Difference at 70: -0, expected -496.625
# E0122 10:44:59.258364   39462 buffer_comparator.cc:157] Difference at 71: -0, expected -503.193
# E0122 10:44:59.258371   39462 buffer_comparator.cc:157] Difference at 72: 0, expected -523.219
# E0122 10:44:59.258377   39462 buffer_comparator.cc:157] Difference at 73: -0, expected -517.057
# 2025-01-22 10:44:59.258394: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.263652   39462 buffer_comparator.cc:157] Difference at 64: 0, expected -512.392
# E0122 10:44:59.263708   39462 buffer_comparator.cc:157] Difference at 65: -0, expected -498.585
# E0122 10:44:59.263715   39462 buffer_comparator.cc:157] Difference at 66: -0, expected -502.718
# E0122 10:44:59.263721   39462 buffer_comparator.cc:157] Difference at 67: 0, expected -516.905
# E0122 10:44:59.263728   39462 buffer_comparator.cc:157] Difference at 68: -0, expected -509.45
# E0122 10:44:59.263735   39462 buffer_comparator.cc:157] Difference at 69: 0, expected -501.301
# E0122 10:44:59.263742   39462 buffer_comparator.cc:157] Difference at 70: -0, expected -496.625
# E0122 10:44:59.263748   39462 buffer_comparator.cc:157] Difference at 71: -0, expected -503.193
# E0122 10:44:59.263754   39462 buffer_comparator.cc:157] Difference at 72: 0, expected -523.219
# E0122 10:44:59.263761   39462 buffer_comparator.cc:157] Difference at 73: -0, expected -517.057
# 2025-01-22 10:44:59.263776: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.268948   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.269000   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.269008   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.269015   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.269022   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.269030   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.269037   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.269045   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.269052   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.269060   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.269082: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.274163   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.274217   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.274224   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.274230   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.274237   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.274243   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.274249   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.274256   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.274262   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.274269   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.274285: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.278849   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.278906   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.278914   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.278920   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.278927   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.278933   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.278939   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.278946   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.278952   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.278959   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.278976: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.283555   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.283611   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.283619   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.283626   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.283632   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.283639   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.283645   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.283651   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.283658   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.283664   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.283679: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.288278   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.288328   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.288334   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.288338   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.288343   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.288348   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.288353   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.288358   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.288362   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.288367   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.288382: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.292791   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.292839   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.292845   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.292849   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.292854   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.292859   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.292864   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.292869   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.292874   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.292878   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.292896: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.297471   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.297521   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.297526   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.297531   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.297536   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.297541   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.297546   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.297550   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.297555   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.297560   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.297577: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.301513   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.301559   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.301565   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.301570   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.301575   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.301580   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.301585   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.301589   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.301594   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.301599   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.301612: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.305575   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.305624   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.305630   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.305634   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.305639   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.305644   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.305649   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.305654   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.305659   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.305663   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.305680: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.309651   39462 buffer_comparator.cc:157] Difference at 128: 0, expected -502.714
# E0122 10:44:59.309697   39462 buffer_comparator.cc:157] Difference at 129: 0, expected -513.305
# E0122 10:44:59.309703   39462 buffer_comparator.cc:157] Difference at 130: -0, expected -509.863
# E0122 10:44:59.309707   39462 buffer_comparator.cc:157] Difference at 131: -0, expected -510.809
# E0122 10:44:59.309712   39462 buffer_comparator.cc:157] Difference at 132: 0, expected -519.548
# E0122 10:44:59.309717   39462 buffer_comparator.cc:157] Difference at 133: -0, expected -505.894
# E0122 10:44:59.309722   39462 buffer_comparator.cc:157] Difference at 134: 0, expected -510.793
# E0122 10:44:59.309727   39462 buffer_comparator.cc:157] Difference at 135: -0, expected -515.006
# E0122 10:44:59.309731   39462 buffer_comparator.cc:157] Difference at 136: -0, expected -508.472
# E0122 10:44:59.309736   39462 buffer_comparator.cc:157] Difference at 137: -0, expected -512.744
# 2025-01-22 10:44:59.309753: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.314053   39462 buffer_comparator.cc:157] Difference at 256: -0, expected -506.212
# E0122 10:44:59.314109   39462 buffer_comparator.cc:157] Difference at 257: -0, expected -510.699
# E0122 10:44:59.314116   39462 buffer_comparator.cc:157] Difference at 258: 0, expected -508.207
# E0122 10:44:59.314123   39462 buffer_comparator.cc:157] Difference at 259: -0, expected -518.049
# E0122 10:44:59.314129   39462 buffer_comparator.cc:157] Difference at 260: -0, expected -513.968
# E0122 10:44:59.314135   39462 buffer_comparator.cc:157] Difference at 261: 0, expected -501.247
# E0122 10:44:59.314141   39462 buffer_comparator.cc:157] Difference at 262: 0, expected -506.017
# E0122 10:44:59.314147   39462 buffer_comparator.cc:157] Difference at 263: 0, expected -505.44
# E0122 10:44:59.314153   39462 buffer_comparator.cc:157] Difference at 264: 0, expected -511.996
# E0122 10:44:59.314159   39462 buffer_comparator.cc:157] Difference at 265: 0, expected -506.772
# 2025-01-22 10:44:59.314174: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.318278   39462 buffer_comparator.cc:157] Difference at 256: -0, expected -506.212
# E0122 10:44:59.318327   39462 buffer_comparator.cc:157] Difference at 257: -0, expected -510.699
# E0122 10:44:59.318333   39462 buffer_comparator.cc:157] Difference at 258: 0, expected -508.207
# E0122 10:44:59.318338   39462 buffer_comparator.cc:157] Difference at 259: -0, expected -518.049
# E0122 10:44:59.318342   39462 buffer_comparator.cc:157] Difference at 260: -0, expected -513.968
# E0122 10:44:59.318347   39462 buffer_comparator.cc:157] Difference at 261: 0, expected -501.247
# E0122 10:44:59.318352   39462 buffer_comparator.cc:157] Difference at 262: 0, expected -506.017
# E0122 10:44:59.318358   39462 buffer_comparator.cc:157] Difference at 263: 0, expected -505.44
# E0122 10:44:59.318363   39462 buffer_comparator.cc:157] Difference at 264: 0, expected -511.996
# E0122 10:44:59.318368   39462 buffer_comparator.cc:157] Difference at 265: 0, expected -506.772
# 2025-01-22 10:44:59.318380: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.322423   39462 buffer_comparator.cc:157] Difference at 256: -0, expected -506.212
# E0122 10:44:59.322476   39462 buffer_comparator.cc:157] Difference at 257: -0, expected -510.699
# E0122 10:44:59.322482   39462 buffer_comparator.cc:157] Difference at 258: 0, expected -508.207
# E0122 10:44:59.322487   39462 buffer_comparator.cc:157] Difference at 259: -0, expected -518.049
# E0122 10:44:59.322491   39462 buffer_comparator.cc:157] Difference at 260: -0, expected -513.968
# E0122 10:44:59.322496   39462 buffer_comparator.cc:157] Difference at 261: 0, expected -501.247
# E0122 10:44:59.322501   39462 buffer_comparator.cc:157] Difference at 262: 0, expected -506.017
# E0122 10:44:59.322506   39462 buffer_comparator.cc:157] Difference at 263: 0, expected -505.44
# E0122 10:44:59.322511   39462 buffer_comparator.cc:157] Difference at 264: 0, expected -511.996
# E0122 10:44:59.322516   39462 buffer_comparator.cc:157] Difference at 265: 0, expected -506.772
# 2025-01-22 10:44:59.322528: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.326487   39462 buffer_comparator.cc:157] Difference at 256: -0, expected -506.212
# E0122 10:44:59.326537   39462 buffer_comparator.cc:157] Difference at 257: -0, expected -510.699
# E0122 10:44:59.326543   39462 buffer_comparator.cc:157] Difference at 258: 0, expected -508.207
# E0122 10:44:59.326548   39462 buffer_comparator.cc:157] Difference at 259: -0, expected -518.049
# E0122 10:44:59.326552   39462 buffer_comparator.cc:157] Difference at 260: -0, expected -513.968
# E0122 10:44:59.326557   39462 buffer_comparator.cc:157] Difference at 261: 0, expected -501.247
# E0122 10:44:59.326562   39462 buffer_comparator.cc:157] Difference at 262: 0, expected -506.017
# E0122 10:44:59.326567   39462 buffer_comparator.cc:157] Difference at 263: 0, expected -505.44
# E0122 10:44:59.326572   39462 buffer_comparator.cc:157] Difference at 264: 0, expected -511.996
# E0122 10:44:59.326577   39462 buffer_comparator.cc:157] Difference at 265: 0, expected -506.772
# 2025-01-22 10:44:59.326588: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.330857   39462 buffer_comparator.cc:157] Difference at 256: -0, expected -506.212
# E0122 10:44:59.330912   39462 buffer_comparator.cc:157] Difference at 257: -0, expected -510.699
# E0122 10:44:59.330917   39462 buffer_comparator.cc:157] Difference at 258: 0, expected -508.207
# E0122 10:44:59.330922   39462 buffer_comparator.cc:157] Difference at 259: -0, expected -518.049
# E0122 10:44:59.330927   39462 buffer_comparator.cc:157] Difference at 260: -0, expected -513.968
# E0122 10:44:59.330932   39462 buffer_comparator.cc:157] Difference at 261: 0, expected -501.247
# E0122 10:44:59.330937   39462 buffer_comparator.cc:157] Difference at 262: 0, expected -506.017
# E0122 10:44:59.330942   39462 buffer_comparator.cc:157] Difference at 263: 0, expected -505.44
# E0122 10:44:59.330947   39462 buffer_comparator.cc:157] Difference at 264: 0, expected -511.996
# E0122 10:44:59.330952   39462 buffer_comparator.cc:157] Difference at 265: 0, expected -506.772
# 2025-01-22 10:44:59.330971: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.335124   39462 buffer_comparator.cc:157] Difference at 128: -0.379851, expected -502.714
# E0122 10:44:59.335170   39462 buffer_comparator.cc:157] Difference at 129: 1.98993, expected -513.305
# E0122 10:44:59.335176   39462 buffer_comparator.cc:157] Difference at 130: 3.37188, expected -509.863
# E0122 10:44:59.335181   39462 buffer_comparator.cc:157] Difference at 131: 2.26466, expected -510.809
# E0122 10:44:59.335186   39462 buffer_comparator.cc:157] Difference at 132: 2.88792, expected -519.548
# E0122 10:44:59.335191   39462 buffer_comparator.cc:157] Difference at 133: 3.52233, expected -505.894
# E0122 10:44:59.335196   39462 buffer_comparator.cc:157] Difference at 134: -0.834496, expected -510.793
# E0122 10:44:59.335201   39462 buffer_comparator.cc:157] Difference at 135: -0.167013, expected -515.006
# E0122 10:44:59.335206   39462 buffer_comparator.cc:157] Difference at 136: -0.65479, expected -508.472
# E0122 10:44:59.335211   39462 buffer_comparator.cc:157] Difference at 137: -0.710862, expected -512.744
# 2025-01-22 10:44:59.335229: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.339300   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected -506.212
# E0122 10:44:59.339345   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected -510.699
# E0122 10:44:59.339351   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected -508.207
# E0122 10:44:59.339356   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected -518.049
# E0122 10:44:59.339361   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected -513.968
# E0122 10:44:59.339366   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected -501.247
# E0122 10:44:59.339371   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected -506.017
# E0122 10:44:59.339376   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected -505.44
# E0122 10:44:59.339381   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected -511.996
# E0122 10:44:59.339386   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected -506.772
# 2025-01-22 10:44:59.339402: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.343454   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected -506.212
# E0122 10:44:59.343499   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected -510.699
# E0122 10:44:59.343505   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected -508.207
# E0122 10:44:59.343510   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected -518.049
# E0122 10:44:59.343515   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected -513.968
# E0122 10:44:59.343520   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected -501.247
# E0122 10:44:59.343525   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected -506.017
# E0122 10:44:59.343530   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected -505.44
# E0122 10:44:59.343535   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected -511.996
# E0122 10:44:59.343540   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected -506.772
# 2025-01-22 10:44:59.343557: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.347654   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected -506.212
# E0122 10:44:59.347703   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected -510.699
# E0122 10:44:59.347708   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected -508.207
# E0122 10:44:59.347713   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected -518.049
# E0122 10:44:59.347718   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected -513.968
# E0122 10:44:59.347723   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected -501.247
# E0122 10:44:59.347728   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected -506.017
# E0122 10:44:59.347733   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected -505.44
# E0122 10:44:59.347738   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected -511.996
# E0122 10:44:59.347743   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected -506.772
# 2025-01-22 10:44:59.347756: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.354190   39462 buffer_comparator.cc:157] Difference at 16: -501.195, expected 82.2036
# E0122 10:44:59.354217   39462 buffer_comparator.cc:157] Difference at 17: -510.363, expected 76.5637
# E0122 10:44:59.354221   39462 buffer_comparator.cc:157] Difference at 18: -514.237, expected 83.5666
# E0122 10:44:59.354224   39462 buffer_comparator.cc:157] Difference at 19: -521.746, expected 88.212
# E0122 10:44:59.354227   39462 buffer_comparator.cc:157] Difference at 20: -500.013, expected 75.9045
# E0122 10:44:59.354230   39462 buffer_comparator.cc:157] Difference at 21: -500.387, expected 78.32
# E0122 10:44:59.354234   39462 buffer_comparator.cc:157] Difference at 22: -505.002, expected 79.9763
# E0122 10:44:59.354237   39462 buffer_comparator.cc:157] Difference at 23: -511.46, expected 78.7399
# E0122 10:44:59.354240   39462 buffer_comparator.cc:157] Difference at 24: -518.995, expected 79.9861
# E0122 10:44:59.354245   39462 buffer_comparator.cc:157] Difference at 25: -500.764, expected 70.1569
# 2025-01-22 10:44:59.354255: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.356152   39462 buffer_comparator.cc:157] Difference at 16: -501.195, expected 82.2036
# E0122 10:44:59.356170   39462 buffer_comparator.cc:157] Difference at 17: -510.363, expected 76.5637
# E0122 10:44:59.356174   39462 buffer_comparator.cc:157] Difference at 18: -514.237, expected 83.5666
# E0122 10:44:59.356177   39462 buffer_comparator.cc:157] Difference at 19: -521.746, expected 88.212
# E0122 10:44:59.356180   39462 buffer_comparator.cc:157] Difference at 20: -500.013, expected 75.9045
# E0122 10:44:59.356184   39462 buffer_comparator.cc:157] Difference at 21: -500.387, expected 78.32
# E0122 10:44:59.356187   39462 buffer_comparator.cc:157] Difference at 22: -505.002, expected 79.9763
# E0122 10:44:59.356190   39462 buffer_comparator.cc:157] Difference at 23: -511.46, expected 78.7399
# E0122 10:44:59.356193   39462 buffer_comparator.cc:157] Difference at 24: -518.995, expected 79.9861
# E0122 10:44:59.356196   39462 buffer_comparator.cc:157] Difference at 25: -500.764, expected 70.1569
# 2025-01-22 10:44:59.356203: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.358037   39462 buffer_comparator.cc:157] Difference at 64: -512.392, expected 74.4595
# E0122 10:44:59.358056   39462 buffer_comparator.cc:157] Difference at 65: -498.585, expected 81.0895
# E0122 10:44:59.358061   39462 buffer_comparator.cc:157] Difference at 66: -502.718, expected 84.2648
# E0122 10:44:59.358065   39462 buffer_comparator.cc:157] Difference at 67: -516.905, expected 79.8491
# E0122 10:44:59.358068   39462 buffer_comparator.cc:157] Difference at 68: -509.45, expected 83.3632
# E0122 10:44:59.358072   39462 buffer_comparator.cc:157] Difference at 69: -501.301, expected 79.1792
# E0122 10:44:59.358076   39462 buffer_comparator.cc:157] Difference at 70: -496.625, expected 80.4217
# E0122 10:44:59.358080   39462 buffer_comparator.cc:157] Difference at 71: -503.193, expected 73.4523
# ...
# E0122 10:44:59.416800   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.416809: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.419681   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.419709   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.419712   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.419715   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.419718   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.419721   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.419724   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.419727   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.419730   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.419733   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.419741: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.422512   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.422539   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.422542   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.422546   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.422549   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.422552   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.422555   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.422558   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.422561   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.422564   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.422571: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.425353   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.425380   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.425384   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.425387   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.425391   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.425394   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.425397   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.425400   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.425403   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.425406   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.425413: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.428289   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.428320   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.428324   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.428327   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.428330   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.428333   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.428336   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.428339   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.428342   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.428345   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.428353: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.431293   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.431321   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.431324   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.431327   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.431330   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.431334   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.431337   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.431340   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.431343   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.431346   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.431355: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.434142   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.434172   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.434176   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.434180   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.434183   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.434186   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.434189   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.434192   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.434195   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.434198   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.434206: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.437097   39462 buffer_comparator.cc:157] Difference at 128: -502.385, expected 75.1208
# E0122 10:44:59.437126   39462 buffer_comparator.cc:157] Difference at 129: -512.969, expected 74.5298
# E0122 10:44:59.437129   39462 buffer_comparator.cc:157] Difference at 130: -509.542, expected 73.4704
# E0122 10:44:59.437132   39462 buffer_comparator.cc:157] Difference at 131: -510.482, expected 73.0675
# E0122 10:44:59.437136   39462 buffer_comparator.cc:157] Difference at 132: -519.203, expected 84.4534
# E0122 10:44:59.437139   39462 buffer_comparator.cc:157] Difference at 133: -505.561, expected 74.277
# E0122 10:44:59.437142   39462 buffer_comparator.cc:157] Difference at 134: -510.473, expected 75.366
# E0122 10:44:59.437145   39462 buffer_comparator.cc:157] Difference at 135: -514.675, expected 77.8279
# E0122 10:44:59.437148   39462 buffer_comparator.cc:157] Difference at 136: -508.141, expected 73.0312
# E0122 10:44:59.437151   39462 buffer_comparator.cc:157] Difference at 137: -512.394, expected 84.1223
# 2025-01-22 10:44:59.437159: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.440019   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected 74.686
# E0122 10:44:59.440050   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected 83.8399
# E0122 10:44:59.440053   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected 81.6772
# E0122 10:44:59.440056   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected 82.7827
# E0122 10:44:59.440059   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected 80.4951
# E0122 10:44:59.440062   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected 80.6941
# E0122 10:44:59.440065   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected 83.5154
# E0122 10:44:59.440068   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected 84.8773
# E0122 10:44:59.440071   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected 83.8892
# E0122 10:44:59.440074   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected 80.7605
# 2025-01-22 10:44:59.440082: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.442847   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected 74.686
# E0122 10:44:59.442875   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected 83.8399
# E0122 10:44:59.442878   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected 81.6772
# E0122 10:44:59.442884   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected 82.7827
# E0122 10:44:59.442888   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected 80.4951
# E0122 10:44:59.442891   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected 80.6941
# E0122 10:44:59.442894   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected 83.5154
# E0122 10:44:59.442897   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected 84.8773
# E0122 10:44:59.442900   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected 83.8892
# E0122 10:44:59.442903   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected 80.7605
# 2025-01-22 10:44:59.442911: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.445757   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected 74.686
# E0122 10:44:59.445791   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected 83.8399
# E0122 10:44:59.445795   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected 81.6772
# E0122 10:44:59.445798   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected 82.7827
# E0122 10:44:59.445801   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected 80.4951
# E0122 10:44:59.445804   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected 80.6941
# E0122 10:44:59.445807   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected 83.5154
# E0122 10:44:59.445810   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected 84.8773
# E0122 10:44:59.445813   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected 83.8892
# E0122 10:44:59.445816   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected 80.7605
# 2025-01-22 10:44:59.445824: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.448753   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected 74.686
# E0122 10:44:59.448783   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected 83.8399
# E0122 10:44:59.448787   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected 81.6772
# E0122 10:44:59.448790   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected 82.7827
# E0122 10:44:59.448793   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected 80.4951
# E0122 10:44:59.448796   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected 80.6941
# E0122 10:44:59.448799   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected 83.5154
# E0122 10:44:59.448802   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected 84.8773
# E0122 10:44:59.448804   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected 83.8892
# E0122 10:44:59.448807   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected 80.7605
# 2025-01-22 10:44:59.448815: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.451704   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected 74.686
# E0122 10:44:59.451732   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected 83.8399
# E0122 10:44:59.451735   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected 81.6772
# E0122 10:44:59.451738   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected 82.7827
# E0122 10:44:59.451742   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected 80.4951
# E0122 10:44:59.451744   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected 80.6941
# E0122 10:44:59.451747   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected 83.5154
# E0122 10:44:59.451750   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected 84.8773
# E0122 10:44:59.451753   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected 83.8892
# E0122 10:44:59.451756   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected 80.7605
# 2025-01-22 10:44:59.451764: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0122 10:44:59.454557   39462 buffer_comparator.cc:157] Difference at 256: 4.03168, expected 74.686
# E0122 10:44:59.454587   39462 buffer_comparator.cc:157] Difference at 257: 4.66567, expected 83.8399
# E0122 10:44:59.454590   39462 buffer_comparator.cc:157] Difference at 258: 4.39555, expected 81.6772
# E0122 10:44:59.454593   39462 buffer_comparator.cc:157] Difference at 259: -0.565489, expected 82.7827
# E0122 10:44:59.454597   39462 buffer_comparator.cc:157] Difference at 260: 6.82274, expected 80.4951
# E0122 10:44:59.454600   39462 buffer_comparator.cc:157] Difference at 261: 2.94298, expected 80.6941
# E0122 10:44:59.454603   39462 buffer_comparator.cc:157] Difference at 262: 3.98236, expected 83.5154
# E0122 10:44:59.454605   39462 buffer_comparator.cc:157] Difference at 263: 2.38447, expected 84.8773
# E0122 10:44:59.454608   39462 buffer_comparator.cc:157] Difference at 264: 0.484346, expected 83.8892
# E0122 10:44:59.454611   39462 buffer_comparator.cc:157] Difference at 265: -0.549141, expected 80.7605
# 2025-01-22 10:44:59.454619: E external/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1180] Results do not match the reference. This is likely a bug/unexpected loss of precision.

# %%
rng = jax.random.PRNGKey(42)
score_args = {"data_id": node_id, "condition_mask": condition_mask, "edge_mask": edge_mask1}
sample_partial1 = rev.sample(rng, 1000, condition_mask=condition_mask, condition_value=x_o, score_args=score_args)

# %%
rng = jax.random.PRNGKey(42)
score_args = {"data_id": node_id, "condition_mask": condition_mask, "edge_mask": edge_mask2}
sample_partial2 = rev.sample(rng, 1000, condition_mask=condition_mask, condition_value=x_o, score_args=score_args)

# %%
x_o_dict = unravel(x_o)

# %%
# sample = jax.device_put(sample, jax.devices("gpu")[0])
# sample_partial1 = jax.device_put(sample_partial1, jax.devices("gpu")[0])
# sample_partial2 = jax.device_put(sample_partial2, jax.devices("gpu")[0])
# x_o = jax.device_put(data_test_flat[index], jax.devices("gpu")[0])

# %%
thetas_sampled = un_z_score_thetas(sample[:, :2])
thetas_partial1 = un_z_score_thetas(sample_partial1[:, :2])
thetas_partial2 = un_z_score_thetas(sample_partial2[:, :2])
theta_true = un_z_score_thetas(x_o[:2].reshape(1,-1))

# %%
num_samples = len(xs1[42,0,:])
frequencies = jnp.fft.fftfreq(num_samples,1.0)
fft_result = jnp.fft.fft(xs1[42,0,:])

idx = jnp.argsort(frequencies)
frequencies=frequencies[idx]
fft_result=fft_result[idx]

# %%
plt.plot(frequencies, jnp.abs(fft_result))
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.title('Fourier Transform of Time Series')
plt.show()

# %%
fft_result
# Out:
# Array([ 8.596+0.j   ,  5.329+0.978j,  2.013+0.583j, ..., 11.175+6.711j,
#         2.013-0.583j,  5.329-0.978j], dtype=complex64)

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.DataFrame({"theta1":thetas_sampled[:, 0], "theta2":thetas_sampled[:, 1]})

# %%
sns.pairplot(df,kind="kde")

# %%
sns.jointplot(data=df,x="theta1", y="theta2", kind="kde", xlim=[-10,10], ylim=[-15,15])
plt.scatter(theta_true[:,0], theta_true[:,1], color="red")
plt.show()

# %%
sns.jointplot(data=df,x="theta1", y="theta2", kind="hex", xlim=[-10,10], ylim=[-10,10])
plt.scatter(theta_true[:,0], theta_true[:,1], color="red")
plt.show()

# %%
import corner

# %%
data_ = {"theta1":thetas_sampled[:, 0], "theta2":thetas_sampled[:, 1]}

# %%
theta_true
# Out:
# Array([[-0.217,  1.651]], dtype=float32)

# %%
figure = corner.corner(data_, bins=21, range=[[-10,10],[-10,10]],
                       quantiles=[0.16, 0.5, 0.84],show_titles=True,
                       truths=theta_true[0],
                      plot_contours=True,
                      smooth=None)
#axes = np.array(figure.axes).reshape((2, 2))
#axes[1,0].scatter(theta_true[:,0], theta_true[:,1], color="red", zorder=10)
plt.show()

# %%
import matplotlib.gridspec as gridspec

# bins1 = np.linspace(-np.pi, np.pi, 101)
# bins2 = np.linspace(0, np.pi, 101)

#xlim = [-1,1]
#ylim=[1.2,2.0]
xlim = [-4*np.pi,4*np.pi]
ylim=[-4*np.pi,4*np.pi]

bins1 = np.linspace(*xlim, 51)
bins2 = np.linspace(*ylim, 51)


plt.plot(x_o_dict["x0"], lw=0.1, color="black")
plt.title("detector 1")
plt.axis("off")
plt.show()

plt.plot(x_o_dict["x1"],lw=0.1, color="black")
plt.title("detector 2")
plt.axis("off")
plt.show()


plt.hist2d(thetas_sampled[:, 0], thetas_sampled[:, 1], bins=[bins1,bins2], density=False)
plt.scatter(theta_true[:,0], theta_true[:,1], color="red")
plt.colorbar()
# ax1.scatter(theta_true[:,0], theta_true[:,1], color="red")
plt.title("Full posterior (detect. 1+2)", y=1.1)
plt.xlabel("Mass 1")
plt.ylabel("Mass 2")

plt.xlim(xlim)
plt.ylim(ylim)

plt.show()


plt.hist2d(thetas_partial1[:, 0], thetas_partial1[:, 1], bins=[bins1,bins2], density=False)
plt.scatter(theta_true[:,0], theta_true[:,1], color="red")
plt.xlabel("Mass 1")
plt.ylabel("Mass 2")
plt.title("Partial posterior (detect. 1)", y=1.1)

plt.xlim(xlim)
plt.ylim(ylim)

plt.show()


plt.hist2d(thetas_partial2[:, 0], thetas_partial2[:, 1], bins=[bins1,bins2], density=False)
plt.scatter(theta_true[:,0], theta_true[:,1], color="red")
plt.xlabel("Mass 1")
plt.ylabel("Mass 2")
plt.title("Partial posterior (detect. 2)", y=1.1)

plt.xlim(xlim)
plt.ylim(ylim)

plt.show()
